# %% [markdown]
# # Lab 6.01 - Regression analysis

# %%
# Package imports
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Dataframe
import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic plot
import seaborn as sns                               # Advanced dataviz
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Exercise 1: Relation between heart weight and body weight in Cats
#
# ### Part 1
#
# Perform a linear regression analysis on the variables body weight (`Bwt`, dependent variable) and heart weight (`Hwt`, independent variabele).
#
#
# 1. Import the dataset `Cats.csv`.

# %%
cats = pd.read_csv('https://raw.githubusercontent.com/HoGentTIN/dsai-labs/main/data/Cats.csv')
# Show the first few records of the Data Frame
cats.head()
# Out:
#    ID Sex  Hwt  Bwt
# 0   1   F  2.0  7.0
# 1   2   F  2.0  7.4
# 2   3   F  2.0  9.5
# 3   4   F  2.1  7.2
# 4   5   F  2.1  7.3

# %% [markdown]
# 2. Draw a scatter plot of both variables.

# %%
sns.relplot(data=cats,x='Hwt',y='Bwt',hue='Sex')

# %% [markdown]
# 3. Calculate and draw the regression line.

# %%
sns.regplot(data=cats,x='Hwt',y='Bwt')
# Out:
# <Axes: xlabel='Hwt', ylabel='Bwt'>

# %%
# y= ax + b
# alternatieve methode
x=cats.Hwt
y=cats.Bwt
a,b=np.polyfit(x,y,1)

print(f"Regressionline: y = {a} * x + {b}")
# Out:
# Regressionline: y = 4.031757486783179 * x + -0.3510783771969617

# %%
#

# %% [markdown]
# 4. Calculate the correlation coefficient and the coefficient of determination.

# %%
cor = np.corrcoef(
    cats.Hwt,
    cats.Bwt)[0][1]
print(f"R ≈ {cor:.4f}")
print(f"R² ≈ {cor**2:.4f}")
# Out:
# R ≈ 0.8041
# R² ≈ 0.6466

# %% [markdown]
# 5. Interpret the results from the previous steps.

# %%
# er is een stijgend verband en een sterk verband R= 0.8
# R² verteld ons dat 64% vad afh var komt van de onafh variabele

# %% [markdown]
# ### Part 2
#
# 1. Perform a linear regression analysis on the variables body weight (`Bwt`) and heart weight (`Hwt`), but this time **subdivided by gender** (`Sex`). Use the same dataset (`Cats.csv`).

# %%
cats = pd.read_csv('https://raw.githubusercontent.com/HoGentTIN/dsai-labs/main/data/Cats.csv')
# Show the first few records of the Data Frame
cats.head()
# Out:
#    ID Sex  Hwt  Bwt
# 0   1   F  2.0  7.0
# 1   2   F  2.0  7.4
# 2   3   F  2.0  9.5
# 3   4   F  2.1  7.2
# 4   5   F  2.1  7.3

# %% [markdown]
# 2. Draw a scatter plot of both variables for each gender.

# %%
Fcats = cats[cats.Sex == 'F']
Fcats.head()
# Out:
#    ID Sex  Hwt  Bwt
# 0   1   F  2.0  7.0
# 1   2   F  2.0  7.4
# 2   3   F  2.0  9.5
# 3   4   F  2.1  7.2
# 4   5   F  2.1  7.3

# %% [markdown]
# 3. Calculate and draw the regression line.

# %%
sns.relplot(data=Fcats,x='Hwt',y='Bwt')

# %% [markdown]
# 3. Calculate and draw the regression line.

# %%
sns.regplot(data=Fcats,x='Hwt',y='Bwt')
# Out:
# <Axes: xlabel='Hwt', ylabel='Bwt'>

# %%
# y= ax + b
# alternatieve methode
x=Fcats.Hwt
y=Fcats.Bwt
a,b=np.polyfit(x,y,1)

print(f"Regressionline: y = {a} * x + {b}")
# Out:
# Regressionline: y = 2.6364140480591503 * x + 2.981312384473199

# %%
#

# %% [markdown]
# 4. Calculate the correlation coefficient and the coefficient of determination.

# %%
cor = np.corrcoef(
    Fcats.Hwt,
    Fcats.Bwt)[0][1]
print(f"R ≈ {cor:.4f}")
print(f"R² ≈ {cor**2:.4f}")
# Out:
# R ≈ 0.5320
# R² ≈ 0.2831

# %% [markdown]
# 5. Interpret the results from the previous steps.

# %%
# er is een stijgend verband en een minder sterk verband R= 0.5
# R² verteld ons dat 23% vad afh var komt van de onafh variabele

# %%
# Out:
# Regression line: ŷ = -1.1768252533094827 + 4.309818875119161 x

# %% [markdown]
# 4. Calculate the correlation coefficient and the coefficient of determination.

# %% [markdown]
# 5. Interpret the results from the previous steps.

# %% [markdown]
# ### Answers
#
# | Selection |  $\beta_0$ | $\beta_1$ |       $R$ |     $R^2$ |
# | :-------- | ---------: | --------: | --------: | --------: |
# | All       | -0.3510784 | 4.0317575 | 0.8041348 | 0.6466328 |
# | Male      | -1.1768253 | 4.3098189 | 0.7930443 | 0.6289193 |
# | Female    |  2.9813124 |  2.636414 | 0.5320497 | 0.2830768 |
