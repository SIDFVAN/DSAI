# %% [markdown]
# # Lab 7.01 - Time series analysis

# %%
# Package imports for data science and time series analysis in particular
import numpy as np                                  # "Scientific computing"
import pandas as pd                                 # Dataframe
import scipy.stats as stats                         # Statistical tests

import matplotlib.pyplot as plt                     # Basic visualisation
import seaborn as sns                               # Advanced dataviz

from sklearn.linear_model import LinearRegression   # Linear regression model

# Time series analysis
from datetime import datetime
from sklearn.metrics import mean_absolute_error,mean_squared_error
from statsmodels.tsa.api import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ### Exercise 1 - House sales
#
# The file House Sales.csv contains monthly data on the number of new one-family
# houses sold in the United States (in thousands) from January 1991 through December 2011.
# Housing sales were steadily trending upward until about the beginning of 2006, then the
# bottom fell out of the housing market, and sales eventually started trending upward again.
#
# - First Create a time series chart of the data.
# - Add predictions for Simple Moving Average with span of 3, 6 and 12 months to the dataframe.
# - Add predictions for Simple Exponential Smooting to the dataframe.
# - Add predictions for Double Exponential Smoothing to the dataframe.
# - Calculate the MAE to find the best model

# %%
data = pd.read_csv('https://raw.githubusercontent.com/HoGentTIN/dsai-labs/main/data/Monthly%20House%20Sales.csv', delimiter = ";", parse_dates=['Month']).set_index(['Month'])
data.head()
# Out:
# <ipython-input-33-2bc339f49a97>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv('https://raw.githubusercontent.com/HoGentTIN/dsai-labs/main/data/Monthly%20House%20Sales.csv', delimiter = ";", parse_dates=['Month']).set_index(['Month'])
#         Houses Sold
# Month
# jan/91          401
# feb/91          482
# mrt/91          507
# apr/91          508
# mei/91          517

# %% [markdown]
# First Create a time series chart of the data.

# %%
data.plot(y='Houses Sold', figsize=[10,5])
# Out:
# <Axes: xlabel='Month'>

# %%
data.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Add predictions for Simple Moving Average with span of 3, 6 and 12 months to the dataframe.

# %%
data['SMA3'] = data['Houses Sold'].rolling(3).mean()
data['SMA6'] = data['Houses Sold'].rolling(6).mean()
data['SMA12'] = data['Houses Sold'].rolling(12).mean()
data
# Out:
#         Houses Sold        SMA3        SMA6       SMA12
# Month
# jan/91          401         NaN         NaN         NaN
# feb/91          482         NaN         NaN         NaN
# mrt/91          507  463.333333         NaN         NaN
# apr/91          508  499.000000         NaN         NaN
# mei/91          517  510.666667         NaN         NaN
# ...             ...         ...         ...         ...
# aug/11          290  296.000000  302.833333  302.000000
# sep/11          302  295.666667  302.333333  300.833333
# okt/11          307  299.666667  300.833333  302.916667
# nov/11          314  307.666667  301.833333  305.166667
# dec/11          307  309.333333  302.500000  303.166667
#
# [252 rows x 4 columns]

# %%
# shift th first column down one for the forecast next month ()

# %%
data.plot(y=['Houses Sold', 'SMA3',	'SMA6',	'SMA12'], figsize=[10,5])
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Add predictions for Simple Exponential Smooting to the dataframe.

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
# Train the model
data_ses = SimpleExpSmoothing(data['Houses Sold']).fit(smoothing_level=0.3)
data['SES'] = data_ses.level
data.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:559: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _index = to_datetime(index)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:210: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
#         Houses Sold        SMA3        SMA6       SMA12         SES
# Month
# jan/91          401         NaN         NaN         NaN  401.000000
# feb/91          482         NaN         NaN         NaN  425.300000
# mrt/91          507  463.333333         NaN         NaN  449.810000
# apr/91          508  499.000000         NaN         NaN  467.267000
# mei/91          517  510.666667         NaN         NaN  482.186900
# jun/91          516  513.666667  488.500000         NaN  492.330830
# jul/91          511  514.666667  506.833333         NaN  497.931581
# aug/91          526  517.666667  514.166667         NaN  506.352107
# sep/91          487  508.000000  510.833333         NaN  500.546475
# okt/91          524  512.333333  513.500000         NaN  507.582532
# nov/91          575  528.666667  523.166667         NaN  527.807773
# dec/91          558  552.333333  530.166667  509.333333  536.865441
# jan/92          676  603.000000  557.666667  532.250000  578.605809
# feb/92          639  624.333333  576.500000  545.333333  596.724066
# mrt/92          554  623.000000  587.666667  549.250000  583.906846
# apr/92          546  579.666667  591.333333  552.416667  572.534792
# mei/92          554  551.333333  587.833333  555.500000  566.974355
# jun/92          596  565.333333  594.166667  562.166667  575.682048
# jul/92          627  592.333333  586.000000  571.833333  591.077434
# aug/92          636  619.666667  585.500000  581.000000  604.554204

# %%
data.plot(y=['Houses Sold',  'SES'], figsize=[10,5])
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Add predictions for Double Exponential Smoothing to the dataframe.

# %%
from statsmodels.tsa.api import Holt

data_des = Holt(data['Houses Sold']).fit(smoothing_level=.3, smoothing_trend=.3)

data['DES'] = data_des.level + 1*data_des.trend
data.tail()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:559: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _index = to_datetime(index)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:210: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
#         Houses Sold        SMA3        SMA6       SMA12         SES  \
# Month
# aug/11          290  296.000000  302.833333  302.000000  298.628542
# sep/11          302  295.666667  302.333333  300.833333  299.639980
# okt/11          307  299.666667  300.833333  302.916667  301.847986
# nov/11          314  307.666667  301.833333  305.166667  305.493590
# dec/11          307  309.333333  302.500000  303.166667  305.945513
#
#                DES
# Month
# aug/11  301.988522
# sep/11  302.385578
# okt/11  304.578816
# nov/11  309.061989
# dec/11  309.914631

# %%
data.plot(y=['Houses Sold',  'DES'], figsize=[10,5])
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Calculate the MAE to find the best model. First drop the rows with NaN.

# %%
data.head()
# Out:
#         Houses Sold        SMA3  SMA6  SMA12       SES         DES
# Month
# jan/91          401         NaN   NaN    NaN  401.0000  531.410000
# feb/91          482         NaN   NaN    NaN  425.3000  585.850100
# mrt/91          507  463.333333   NaN    NaN  449.8100  624.361661
# apr/91          508  499.000000   NaN    NaN  467.2670  641.147204
# mei/91          517  510.666667   NaN    NaN  482.1869  644.423836

# %%
data.head()
# Out:
#         Houses Sold        SMA3        SMA6       SMA12     EMA_0.1  \
# Month
# dec/91          558  552.333333  530.166667  509.333333  486.485807
# jan/92          676  603.000000  557.666667  532.250000  505.437227
# feb/92          639  624.333333  576.500000  545.333333  518.793504
# mrt/92          554  623.000000  587.666667  549.250000  522.314153
# apr/92          546  579.666667  591.333333  552.416667  524.682738
#
#            EMA_0.5         SES         DES
# Month
# dec/91  551.078613  536.865441  555.861803
# jan/92  613.539307  578.605809  591.006537
# feb/92  626.269653  596.724066  612.157262
# mrt/92  590.134827  583.906846  603.878616
# apr/92  568.067413  572.534792  591.194488

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
columns = ['SMA3', 'SMA6', 'SMA12', 'SES', 'DES']

# %%
for c in columns:
  data[c]=data[c].shift(1)
data=data.dropna()

for c in columns:
  print(f'MAE {c}   = {mean_absolute_error(data["Houses Sold"],data[c])}')
# Out:
# MAE SMA3   = 40.86666666666666
# MAE SMA6   = 46.57916666666666
# MAE SMA12   = 62.24791666666667
# MAE SES   = 43.55338386520248
# MAE DES   = 40.34109136262235

# %% [markdown]
# ## Source
# Business Analytics Data Analysis & Decision Making
